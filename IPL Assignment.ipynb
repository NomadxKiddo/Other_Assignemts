# %%
# Necessary Libraries

import numpy as np, pandas as pd

# %% [markdown]
# ### 1. Load the data

# %%
# Lets load the data

data = pd.read_excel(r'C:\Users\joshu\Desktop\prwa Tech\Assignments\2 IPL\Workings\IPL_Matches_2008-2020.xlsx')

# %% [markdown]
# ### 2. Display the data

# %%
data.head()
# Out:
#        id        city       date player_of_match  \
# 0  335982   Bangalore 2008-04-18     BB McCullum
# 1  335983  Chandigarh 2008-04-19      MEK Hussey
# 2  335984       Delhi 2008-04-19     MF Maharoof
# 3  335985      Mumbai 2008-04-20      MV Boucher
# 4  335986     Kolkata 2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
data.tail()
# Out:
#           id       city       date player_of_match  \
# 811  1216547      Dubai 2020-09-28  AB de Villiers
# 812  1237177      Dubai 2020-11-05       JJ Bumrah
# 813  1237178  Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180  Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181      Dubai 2020-11-10        TA Boult
#
#                                    venue  neutral_venue  \
# 811  Dubai International Cricket Stadium              0
# 812  Dubai International Cricket Stadium              0
# 813                 Sheikh Zayed Stadium              0
# 814                 Sheikh Zayed Stadium              0
# 815  Dubai International Cricket Stadium              0
#
#                            team1                team2          toss_winner  \
# 811  Royal Challengers Bangalore       Mumbai Indians       Mumbai Indians
# 812               Mumbai Indians       Delhi Capitals       Delhi Capitals
# 813  Royal Challengers Bangalore  Sunrisers Hyderabad  Sunrisers Hyderabad
# ...

# %% [markdown]
# ### 3. Schema

# %%
data.describe()
# Out:
#                  id  neutral_venue  result_margin
# count  8.160000e+02     816.000000     799.000000
# mean   7.563496e+05       0.094363      17.321652
# std    3.058943e+05       0.292512      22.068427
# min    3.359820e+05       0.000000       1.000000
# 25%    5.012278e+05       0.000000       6.000000
# 50%    7.292980e+05       0.000000       8.000000
# 75%    1.082626e+06       0.000000      19.500000
# max    1.237181e+06       1.000000     146.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    object
#  2   date             816 non-null    datetime64[ns]
#  3   player_of_match  812 non-null    object
#  4   venue            816 non-null    object
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    object
#  7   team2            816 non-null    object
#  8   toss_winner      816 non-null    object
#  9   toss_decision    816 non-null    object
#  10  winner           812 non-null    object
#  11  result           812 non-null    object
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    object
#  14  method           19 non-null     object
#  15  umpire1          816 non-null    object
# ...

# %%
data.shape
# Out:
# (816, 17)

# %%
data.columns
# Out:
# Index(['id', 'city', 'date', 'player_of_match', 'venue', 'neutral_venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'eliminator', 'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
# Lets check null values

for x in data.columns:
    print(f'{x} - {sum(data[x].isnull())}')
# Out:
# id - 0
# city - 13
# date - 0
# player_of_match - 4
# venue - 0
# neutral_venue - 0
# team1 - 0
# team2 - 0
# toss_winner - 0
# toss_decision - 0
# winner - 4
# result - 4
# result_margin - 17
# eliminator - 4
# method - 797
# umpire1 - 0
# umpire2 - 0

# %% [markdown]
# ### 4. Splitting 2nd column

# %%
data.city.value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Ahmedabad          12
# Sharjah            12
# Centurion          12
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
cities = data.city.value_counts()
cities_df = pd.DataFrame(cities).reset_index()
cities_df.columns = ['Cities', 'No. of IPL Matches']
cities_df
# Out:
#             Cities  No. of IPL Matches
# 0           Mumbai                 101
# 1          Kolkata                  77
# 2            Delhi                  74
# 3        Bangalore                  65
# 4        Hyderabad                  64
# 5          Chennai                  57
# 6       Chandigarh                  56
# 7           Jaipur                  47
# 8             Pune                  38
# 9        Abu Dhabi                  29
# 10           Dubai                  26
# 11       Bengaluru                  15
# 12          Durban                  15
# 13   Visakhapatnam                  13
# 14       Ahmedabad                  12
# 15         Sharjah                  12
# 16       Centurion                  12
# 17          Rajkot                  10
# 18      Dharamsala                   9
# 19          Indore                   9
# 20    Johannesburg                   8
# 21         Cuttack                   7
# 22       Cape Town                   7
# ...

# %% [markdown]
# ### 5. City which conducted the highest number of IPL Matches

# %%
cities_df.iloc[0,:]
# Out:
# Cities                Mumbai
# No. of IPL Matches       101
# Name: 0, dtype: object

# %% [markdown]
# ##### Mumbai Conducted 101 IPL Martches

# %% [markdown]
# ### 6. Matches conducted in Bangalore

# %%
bang_data = data[data.city == 'Bangalore']
bang_data
# Out:
#           id       city       date  player_of_match                  venue  \
# 0     335982  Bangalore 2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 10    335992  Bangalore 2008-04-26        SR Watson  M Chinnaswamy Stadium
# 14    335996  Bangalore 2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 24    336006  Bangalore 2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 30    336012  Bangalore 2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..       ...        ...        ...              ...                    ...
# 606  1082621  Bangalore 2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  Bangalore 2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  Bangalore 2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  Bangalore 2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  Bangalore 2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
# ...

# %%
# Saving as an Excel file

bang_data.to_excel('Bang_data.xlsx')

# %% [markdown]
# ### 7. Display the saved file

# %%
bang_data.head()
# Out:
#         id       city       date player_of_match                  venue  \
# 0   335982  Bangalore 2008-04-18     BB McCullum  M Chinnaswamy Stadium
# 10  335992  Bangalore 2008-04-26       SR Watson  M Chinnaswamy Stadium
# 14  335996  Bangalore 2008-04-28        MS Dhoni  M Chinnaswamy Stadium
# 24  336006  Bangalore 2008-05-05     S Sreesanth  M Chinnaswamy Stadium
# 30  336012  Bangalore 2008-05-28    CRD Fernando  M Chinnaswamy Stadium
#
#     neutral_venue                        team1                  team2  \
# 0               0  Royal Challengers Bangalore  Kolkata Knight Riders
# 10              0  Royal Challengers Bangalore       Rajasthan Royals
# 14              0  Royal Challengers Bangalore    Chennai Super Kings
# 24              0  Royal Challengers Bangalore        Kings XI Punjab
# 30              0  Royal Challengers Bangalore         Mumbai Indians
#
#                     toss_winner toss_decision                 winner   result  \
# ...

# %%
bang_data.tail()
# Out:
#           id       city       date  player_of_match                  venue  \
# 606  1082621  Bangalore 2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  Bangalore 2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  Bangalore 2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  Bangalore 2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  Bangalore 2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
#      neutral_venue                        team1                  team2  \
# 606              0  Royal Challengers Bangalore          Gujarat Lions
# 618              0  Royal Challengers Bangalore        Kings XI Punjab
# 621              0  Royal Challengers Bangalore  Kolkata Knight Riders
# 633              0          Sunrisers Hyderabad  Kolkata Knight Riders
# 634              0               Mumbai Indians  Kolkata Knight Riders
#
#                      toss_winner toss_decision                 winner  \
# ...

# %%
bang_data
# Out:
#           id       city       date  player_of_match                  venue  \
# 0     335982  Bangalore 2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 10    335992  Bangalore 2008-04-26        SR Watson  M Chinnaswamy Stadium
# 14    335996  Bangalore 2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 24    336006  Bangalore 2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 30    336012  Bangalore 2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..       ...        ...        ...              ...                    ...
# 606  1082621  Bangalore 2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  Bangalore 2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  Bangalore 2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  Bangalore 2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  Bangalore 2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
# ...

# %% [markdown]
# ### 8. Matches played in 2015

# %%
# Lets create new column named Year and store year in it

data['date'] = pd.to_datetime(data['date'])
data['year'] = data.date.dt.year
data
# Out:
#           id        city       date player_of_match  \
# 0     335982   Bangalore 2008-04-18     BB McCullum
# 1     335983  Chandigarh 2008-04-19      MEK Hussey
# 2     335984       Delhi 2008-04-19     MF Maharoof
# 3     335985      Mumbai 2008-04-20      MV Boucher
# 4     335986     Kolkata 2008-04-20       DJ Hussey
# ..       ...         ...        ...             ...
# 811  1216547       Dubai 2020-09-28  AB de Villiers
# 812  1237177       Dubai 2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi 2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi 2020-11-08      MP Stoinis
# 815  1237181       Dubai 2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
yr_2015 = data[data.year == 2015]
yr_2015
# Out:
#          id           city       date  player_of_match  \
# 458  829705        Kolkata 2015-04-08         M Morkel
# 459  829707        Chennai 2015-04-09          A Nehra
# 460  829709           Pune 2015-04-10      JP Faulkner
# 461  829711        Chennai 2015-04-11      BB McCullum
# 462  829713        Kolkata 2015-04-11         CH Gayle
# 463  829715          Delhi 2015-04-12         DJ Hooda
# 464  829717         Mumbai 2015-04-12        GJ Bailey
# 465  829719      Bangalore 2015-04-13        DA Warner
# 466  829721      Ahmedabad 2015-04-14        SPD Smith
# 467  829723        Kolkata 2015-04-30       AD Russell
# 468  829725           Pune 2015-04-15       MA Agarwal
# 469  829727  Visakhapatnam 2015-04-16        AM Rahane
# 470  829729         Mumbai 2015-04-17          A Nehra
# 471  829731  Visakhapatnam 2015-04-18        JP Duminy
# 472  829733           Pune 2015-04-18       AD Russell
# 473  829735      Ahmedabad 2015-04-19        AM Rahane
# ...

# %% [markdown]
# ### 9. Top Men of the match

# %%
men_of_the_match = data.player_of_match.value_counts()

# %% [markdown]
# ### 10. Result (Top Men of the match)

# %%
men_of_the_match_df = pd.DataFrame(men_of_the_match).reset_index()
men_of_the_match_df.columns = ['Players', 'n times']

# %%
men_of_the_match_df.iloc[0,:]
# Out:
# Players    AB de Villiers
# n times                23
# Name: 0, dtype: object
